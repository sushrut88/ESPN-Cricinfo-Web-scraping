# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
url="https://www.espncricinfo.com/records/most-runs-in-career-83548"
headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36","Accept-Language":"en-US,en;q=0.5"}
webpage=requests.get(url,headers=headers)
webpage
# Out:
# <Response [200]>

# %%
webpage.content
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><link rel="preconnect" href="https://img1.hscicdn.com" crossorigin="anonymous"/><link rel="preconnect" href="https://dcf.espn.com" crossorigin="anonymous"/><link rel="preload" href="https://wassets.hscicdn.com/static/fonts/CiIcons/ci-icons-v3.2/fonts/icomoon.woff?gencn3" as="font" type="font/woff2" crossorigin="anonymous"/><link rel="preload" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Bold/BentonSans-Bold.woff" as="font" type="font/woff" crossorigin="anonymous"/><link rel="preload" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Regular/BentonSans-Regular.woff" as="font" type="font/woff" crossorigin="anonymous"/><link rel="preload" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Medium/BentonSans-Medium.woff" as="font" type="font/woff" crossorigin="anonymous"/><script type="text/javascript">\n          /*! js-cookie v3.0.5 | MIT */\n          !function(e,t
# ...

# %%
soup=BeautifulSoup(webpage.content,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link crossorigin="anonymous" href="https://img1.hscicdn.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://dcf.espn.com" rel="preconnect"/>
#   <link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/CiIcons/ci-icons-v3.2/fonts/icomoon.woff?gencn3" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Bold/BentonSans-Bold.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Regular/BentonSans-Regular.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Medium/BentonSans-Medium.woff" rel="preload" type="font/woff"/>
#   <script type="text/javascript">
# ...

# %%
Batter=soup.find_all("span",class_="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block")
Batter
# Out:
# [<span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">SR Tendulkar (IND)</span>,
#  <span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">KC Sangakkara (Asia/ICC/SL)</span>,
#  <span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">V Kohli (IND)</span>,
#  <span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">RT Ponting (AUS/ICC)</span>,
#  <span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">ST Jayasuriya (Asia/SL)</span>,
#  <span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">DPMD Jayawardene (Asia/SL)</span>,
#  <span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">Inzamam-ul-Haq (Asia/PAK)</span>,
# ...

# %%
Batsman=[]
for Each_Batsman in Batter:
    Batsman.append(Each_Batsman.get_text().strip())
Batsman
# Out:
# ['SR Tendulkar (IND)',
#  'KC Sangakkara (Asia/ICC/SL)',
#  'V Kohli (IND)',
#  'RT Ponting (AUS/ICC)',
#  'ST Jayasuriya (Asia/SL)',
#  'DPMD Jayawardene (Asia/SL)',
#  'Inzamam-ul-Haq (Asia/PAK)',
#  'JH Kallis (Afr/ICC/SA)',
#  'SC Ganguly (Asia/IND)',
#  'R Dravid (Asia/ICC/IND)',
#  'MS Dhoni (Asia/IND)',
#  'RG Sharma (IND)',
#  'CH Gayle (ICC/WI)',
#  'BC Lara (ICC/WI)',
#  'TM Dilshan (SL)',
#  'Mohammad Yousuf (Asia/PAK)',
#  'AC Gilchrist (AUS/ICC)',
#  'AB de Villiers (Afr/SA)',
#  'M Azharuddin (IND)',
#  'PA de Silva (SL)',
#  'Saeed Anwar (PAK)',
#  'S Chanderpaul (WI)',
#  'Yuvraj Singh (Asia/IND)',
#  'DL Haynes (WI)',
#  'LRPL Taylor (NZ)',
#  'MS Atapattu (SL)',
#  'ME Waugh (AUS)',
#  'Tamim Iqbal (BAN)',
#  'V Sehwag (Asia/ICC/IND)',
#  'HM Amla (SA)',
#  'HH Gibbs (SA)',
#  'Shahid Afridi (Asia/ICC/PAK)',
#  'SP Fleming (ICC/NZ)',
#  'MJ Clarke (AUS)',
#  'Mushfiqur Rahim (BAN)',
#  'EJG Morgan (ENG/IRE)',
#  'Shakib Al Hasan (BAN)',
#  'SR Waugh (AUS)',
# ...

# %%
df=pd.DataFrame()
df["Player"]=Batsman
df.head()
# Out:
#                         Player
# 0           SR Tendulkar (IND)
# 1  KC Sangakkara (Asia/ICC/SL)
# 2                V Kohli (IND)
# 3         RT Ponting (AUS/ICC)
# 4      ST Jayasuriya (Asia/SL)
